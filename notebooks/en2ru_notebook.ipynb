# %%
# !pip install dvc[gdrive]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.5/438.5 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.9/209.9 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/aksel2904/en2ru.git
# Out:
# Cloning into 'en2ru'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 192 (delta 79), reused 145 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (192/192), 70.62 KiB | 3.21 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# %cd en2ru
# Out:
# /content/en2ru

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/en2ru
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for en2ru (pyproject.toml) ... done
#   Created wheel for en2ru: filename=en2ru-0.1-0.editable-py3-none-any.whl size=1085 sha256=bec192a6bff7a12896802fe1b4a6fbdce6cd76ff3db32b38487790f91eb2c72b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c5vmczsa/wheels/3a/2d/d7/4ecad4d2b053ec36ff71ee06d065cfe59b64826c8951366845
# Successfully built en2ru
# ...

# %%
'''!dvc config core.remote myremote
# !dvc remote add -d myremote gdrive://1tfX5r39iOMCZs7DbkB7s0Lwj-Fu1aWCm
# !dvc remote modify myremote gdrive_use_service_account true
# !dvc remote modify myremote gdrive_service_account_json_file_path dvc-sa.json'''
# Out:
# '!dvc config core.remote myremote\n!dvc remote add -d myremote gdrive://1tfX5r39iOMCZs7DbkB7s0Lwj-Fu1aWCm\n!dvc remote modify myremote gdrive_use_service_account true\n!dvc remote modify myremote gdrive_service_account_json_file_path dvc-sa.json'

# %%
# dvc-sa.json - загрузить перед этим в корень en2ru
# !dvc pull
# Out:
# ...
# Fetching
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Querying remote cache:   0% 0/3 [00:00<?, ?files/s]
# Querying remote cache:   0% 0/3 [00:00<?, ?files/s{'info': ''}]
# Querying remote cache:  33% 1/3 [00:00<00:00,  2.29files/s{'info': ''}]
#
# Fetching from gdrive:   0% 0/21 [00:00<?, ?file/s]
# Fetching from gdrive:   0% 0/21 [00:00<?, ?file/s{'info': ''}]
# Fetching from gdrive:   0% 0/6 [00:00<?, ?file/s{'info': ''}]
#
#   0% 0.00/54.0M [00:00<?, ?B/s]
#
#   0% 0.00/54.0M [00:00<?, ?B/s{'info': ''}]
#
# 100% 54.0M/54.0M [00:04<00:00, 13.4MB/s{'info': ''}]
#
#
# Fetching from gdrive:  17% 1/6 [00:05<00:25,  5.05s/file{'info': ''}]
#
#   0% 0.00/108M [00:00<?, ?B/s]
#
#   0% 0.00/108M [00:00<?, ?B/s{'info': ''}]
#
#
#   0% 0.00/20.3M [00:00<?, ?B/s]
#
#
#   0% 0.00/20.3M [00:00<?, ?B/s{'info': ''}]
#
#
#
#   0% 0.00/10.8M [00:00<?, ?B/s]
#
#
#
#   0% 0.00/10.8M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#   0% 0.00/204M [00:00<?, ?B/s]
#
#
#
#
# ...

# %%
# !python scripts/preprocess.py
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/data1/split_small/train.en
#   input_format:
#   model_prefix: data/data1/split_small/bpe_en
#   model_type: BPE
#   vocab_size: 5500
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <bos>
#   user_defined_symbols: <eos>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 2
# ...

# %%
# !python src/train.py
# Out:
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# 🚀 Запуск обучения с конфигом:
# data:
#   dataset1_small_en: data/data1/dataset1_small.en
#   dataset1_small_ru: data/data1/dataset1_small.ru
#   dataset1_medium_en: data/data1/dataset1_medium.en
#   dataset1_medium_ru: data/data1/dataset1_medium.ru
#   dataset1_en: data/data1/dataset1.en
#   dataset1_ru: data/data1/dataset1.ru
#   dataset2_small_en: data/data2/dataset2_small.en
#   dataset2_small_ru: data/data2/dataset2_small.ru
#   dataset2_medium_en: data/data2/dataset2_medium.en
#   dataset2_medium_ru: data/data2/dataset2_medium.ru
#   dataset2_en: data/data2/dataset2.en
#   dataset2_ru: data/data2/dataset2.ru
#   dataset3_small_en: data/data3/dataset3_small.en
# ...

# %%
# !python src/inference.py
# Out:
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Примеры перевода:
# 1. "в этом, что я не
# 2. "в этом, что в том, что не только не только в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в том, что в
# ...

# %%
# !python scripts/save_metrics.py
# Out:
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Saved metrics:
# {
#   "bleu": 0.01
# }

# %%
# !dvc add weights/best.ckpt
# !dvc add outputs/predictions.txt
# !dvc add outputs/metrics.json
# Out:
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Adding weights/best.ckpt to cache:   0% 0/1 [00:00<?, ?file/s]
# Adding weights/best.ckpt to cache:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
#
# Checking out /content/en2ru/weights/best.ckpt:   0% 0/1 [00:00<?, ?files/s]
#   0% 0/1 [00:00<?, ?files/s{'info': ''}]
# Adding...: 100% 1/1 [00:00<00:00, 15.69file/s{'info': ''}]
#
# To track the changes with git, run:
#
# 	git add weights/best.ckpt.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
#           |0.00 [00:00,     ?file/s]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Adding outputs/predictions.txt to cache:   0% 0/1 [00:00<?, ?file/s]
# Adding outputs/predictions.txt to cache:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
#
#   0% 0/1 [00:00<?, ?files/s]
# ...

# %% [markdown]
# Тут только надо добавить "авторизацию" по токену, чтобы было можно запушить...

# %%
# !git config --global user.name "aksel2904"
# !git config --global user.email "aksel2904@gmail.com"

# !git add weights/*.dvc outputs/*.dvc .gitignore
# !git commit -m "exp: , BLEU="
# !dvc push
