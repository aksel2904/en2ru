# %%
# !pip install dvc[gdrive]
# Out:
# Collecting dvc[gdrive]
#   Downloading dvc-3.59.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (25.3.0)
# Collecting celery (from dvc[gdrive])
#   Downloading celery-5.5.1-py3-none-any.whl.metadata (22 kB)
# Collecting colorama>=0.3.9 (from dvc[gdrive])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting configobj>=5.0.9 (from dvc[gdrive])
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: distro>=1.3 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (1.9.0)
# Collecting dpath<3,>=2.1.0 (from dvc[gdrive])
#   Downloading dpath-2.2.0-py3-none-any.whl.metadata (15 kB)
# Collecting dulwich (from dvc[gdrive])
#   Downloading dulwich-0.22.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting dvc-data<3.17,>=3.16.2 (from dvc[gdrive])
#   Downloading dvc_data-3.16.9-py3-none-any.whl.metadata (5.0 kB)
# Collecting dvc-http>=2.29.0 (from dvc[gdrive])
#   Downloading dvc_http-2.32.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting dvc-objects (from dvc[gdrive])
#   Downloading dvc_objects-5.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting dvc-render<2,>=1.0.1 (from dvc[gdrive])
#   Downloading dvc_render-1.0.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dvc-studio-client<1,>=0.21 (from dvc[gdrive])
#   Downloading dvc_studio_client-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting dvc-task<1,>=0.3.0 (from dvc[gdrive])
#   Downloading dvc_task-0.40.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting flatten_dict<1,>=0.4.1 (from dvc[gdrive])
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting flufl.lock<9,>=8.1.0 (from dvc[gdrive])
#   Downloading flufl_lock-8.1.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: fsspec>=2024.2.0 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (2025.3.2)
# Collecting funcy>=1.14 (from dvc[gdrive])
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting grandalf<1,>=0.7 (from dvc[gdrive])
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting gto<2,>=1.6.0 (from dvc[gdrive])
#   Downloading gto-1.7.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting hydra-core>=1.1 (from dvc[gdrive])
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting iterative-telemetry>=0.0.7 (from dvc[gdrive])
#   Downloading iterative_telemetry-0.0.10-py3-none-any.whl.metadata (4.1 kB)
# Collecting kombu (from dvc[gdrive])
#   Downloading kombu-5.5.3-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (3.4.2)
# Collecting omegaconf (from dvc[gdrive])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=19 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (24.2)
# Collecting pathspec>=0.10.3 (from dvc[gdrive])
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (4.3.7)
# Requirement already satisfied: psutil>=5.8 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (5.9.5)
# Requirement already satisfied: pydot>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (3.0.4)
# Collecting pygtrie>=2.3.2 (from dvc[gdrive])
#   Downloading pygtrie-2.5.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (3.2.3)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (2.32.3)
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (13.9.4)
# Collecting ruamel.yaml>=0.17.11 (from dvc[gdrive])
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Collecting scmrepo<4,>=3.3.8 (from dvc[gdrive])
#   Downloading scmrepo-3.3.10-py3-none-any.whl.metadata (4.8 kB)
# Collecting shortuuid>=0.5 (from dvc[gdrive])
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting shtab<2,>=1.3.4 (from dvc[gdrive])
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (0.9.0)
# Collecting tomlkit>=0.11.1 (from dvc[gdrive])
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /usr/local/lib/python3.11/dist-packages (from dvc[gdrive]) (4.67.1)
# Collecting voluptuous>=0.11.7 (from dvc[gdrive])
#   Downloading voluptuous-0.15.2-py3-none-any.whl.metadata (20 kB)
# Collecting zc.lockfile>=1.2.1 (from dvc[gdrive])
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl.metadata (6.2 kB)
# Collecting dvc-gdrive<4,>=3 (from dvc[gdrive])
#   Downloading dvc_gdrive-3.0.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting dictdiffer>=0.8.1 (from dvc-data<3.17,>=3.16.2->dvc[gdrive])
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting diskcache>=5.2.1 (from dvc-data<3.17,>=3.16.2->dvc[gdrive])
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting sqltrie<1,>=0.11.0 (from dvc-data<3.17,>=3.16.2->dvc[gdrive])
#   Downloading sqltrie-0.11.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: orjson<4,>=3 in /usr/local/lib/python3.11/dist-packages (from dvc-data<3.17,>=3.16.2->dvc[gdrive]) (3.10.16)
# Requirement already satisfied: pydrive2>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.21.3)
# Collecting aiohttp-retry>=2.5.0 (from dvc-http>=2.29.0->dvc[gdrive])
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting billiard<5.0,>=4.2.1 (from celery->dvc[gdrive])
#   Downloading billiard-4.2.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting vine<6.0,>=5.1.0 (from celery->dvc[gdrive])
#   Downloading vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9.0,>=8.1.2 in /usr/local/lib/python3.11/dist-packages (from celery->dvc[gdrive]) (8.1.8)
# Collecting click-didyoumean>=0.3.0 (from celery->dvc[gdrive])
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-repl>=0.2.0 (from celery->dvc[gdrive])
#   Downloading click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting click-plugins>=1.1.1 (from celery->dvc[gdrive])
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from celery->dvc[gdrive]) (2.8.2)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.11/dist-packages (from flatten_dict<1,>=0.4.1->dvc[gdrive]) (1.17.0)
# Requirement already satisfied: atpublic in /usr/local/lib/python3.11/dist-packages (from flufl.lock<9,>=8.1.0->dvc[gdrive]) (5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.4)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (2.11.3)
# Collecting semver>=2.13.0 (from gto<2,>=1.6.0->dvc[gdrive])
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.15.2)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->dvc[gdrive])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting appdirs (from iterative-telemetry>=0.0.7->dvc[gdrive])
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from iterative-telemetry>=0.0.7->dvc[gdrive]) (3.18.0)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu->dvc[gdrive])
#   Downloading amqp-5.3.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.11/dist-packages (from kombu->dvc[gdrive]) (2025.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf->dvc[gdrive]) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->dvc[gdrive]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->dvc[gdrive]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->dvc[gdrive]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22->dvc[gdrive]) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12->dvc[gdrive]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12->dvc[gdrive]) (2.18.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.11->dvc[gdrive])
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: gitpython>3 in /usr/local/lib/python3.11/dist-packages (from scmrepo<4,>=3.3.8->dvc[gdrive]) (3.1.44)
# Requirement already satisfied: pygit2>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from scmrepo<4,>=3.3.8->dvc[gdrive]) (1.17.0)
# Collecting asyncssh<3,>=2.13.1 (from scmrepo<4,>=3.3.8->dvc[gdrive])
#   Downloading asyncssh-2.20.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zc.lockfile>=1.2.1->dvc[gdrive]) (75.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (3.11.15)
# Requirement already satisfied: cryptography>=39.0 in /usr/local/lib/python3.11/dist-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.3.8->dvc[gdrive]) (43.0.3)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.3.8->dvc[gdrive]) (4.13.1)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /usr/local/lib/python3.11/dist-packages (from click-repl>=0.2.0->celery->dvc[gdrive]) (3.0.50)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>3->scmrepo<4,>=3.3.8->dvc[gdrive]) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12->dvc[gdrive]) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc[gdrive]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc[gdrive]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc[gdrive]) (0.4.0)
# Requirement already satisfied: google-api-python-client>=1.12.5 in /usr/local/lib/python3.11/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.164.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.1.3)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (24.2.1)
# Requirement already satisfied: cffi>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from pygit2>=1.14.0->scmrepo<4,>=3.3.8->dvc[gdrive]) (1.17.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc[gdrive]) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.19.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.17.0->pygit2>=1.14.0->scmrepo<4,>=3.3.8->dvc[gdrive]) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.3.8->dvc[gdrive]) (5.0.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.4.2)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.9)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc[gdrive]) (0.2.13)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (5.5.2)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Downloading dpath-2.2.0-py3-none-any.whl (17 kB)
# Downloading dvc_data-3.16.9-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 7.4 MB/s eta 0:00:00
# Downloading dvc_gdrive-3.0.1-py3-none-any.whl (11 kB)
# Downloading dvc_http-2.32.0-py3-none-any.whl (12 kB)
# Downloading dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# Downloading dvc_render-1.0.2-py3-none-any.whl (22 kB)
# Downloading dvc_studio_client-0.21.0-py3-none-any.whl (16 kB)
# Downloading dvc_task-0.40.2-py3-none-any.whl (21 kB)
# Downloading celery-5.5.1-py3-none-any.whl (438 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.5/438.5 kB 30.6 MB/s eta 0:00:00
# Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Downloading flufl_lock-8.1.0-py3-none-any.whl (11 kB)
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
# Downloading gto-1.7.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.8 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.9 MB/s eta 0:00:00
# Downloading iterative_telemetry-0.0.10-py3-none-any.whl (10 kB)
# Downloading kombu-5.5.3-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.9/209.9 kB 16.5 MB/s eta 0:00:00
# Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.8 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.2 MB/s eta 0:00:00
# Downloading scmrepo-3.3.10-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 6.5 MB/s eta 0:00:00
# Downloading dulwich-0.22.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.6 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading voluptuous-0.15.2-py3-none-any.whl (31 kB)
# Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Downloading dvc-3.59.1-py3-none-any.whl (457 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.7/457.7 kB 34.7 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading amqp-5.3.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
# Downloading asyncssh-2.20.0-py3-none-any.whl (373 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 29.0 MB/s eta 0:00:00
# Downloading billiard-4.2.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 44.9 MB/s eta 0:00:00
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading sqltrie-0.11.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=2380c785979b5ea9ed6403670c9b840cfea5611dc4a5c7186587911f51c7276c
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# Installing collected packages: pygtrie, funcy, dictdiffer, appdirs, antlr4-python3-runtime, zc.lockfile, voluptuous, vine, tomlkit, sqltrie, shtab, shortuuid, semver, ruamel.yaml.clib, pathspec, omegaconf, grandalf, flufl.lock, flatten_dict, dvc-render, dvc-objects, dulwich, dpath, diskcache, configobj, colorama, click-plugins, click-didyoumean, billiard, ruamel.yaml, iterative-telemetry, hydra-core, dvc-studio-client, dvc-data, click-repl, amqp, kombu, asyncssh, aiohttp-retry, scmrepo, dvc-http, celery, gto, dvc-task, dvc, dvc-gdrive
# Successfully installed aiohttp-retry-2.9.1 amqp-5.3.1 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 asyncssh-2.20.0 billiard-4.2.1 celery-5.5.1 click-didyoumean-0.3.1 click-plugins-1.1.1 click-repl-0.3.0 colorama-0.4.6 configobj-5.0.9 dictdiffer-0.9.0 diskcache-5.6.3 dpath-2.2.0 dulwich-0.22.8 dvc-3.59.1 dvc-data-3.16.9 dvc-gdrive-3.0.1 dvc-http-2.32.0 dvc-objects-5.1.0 dvc-render-1.0.2 dvc-studio-client-0.21.0 dvc-task-0.40.2 flatten_dict-0.4.2 flufl.lock-8.1.0 funcy-2.0 grandalf-0.8 gto-1.7.2 hydra-core-1.3.2 iterative-telemetry-0.0.10 kombu-5.5.3 omegaconf-2.3.0 pathspec-0.12.1 pygtrie-2.5.0 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 scmrepo-3.3.10 semver-3.0.4 shortuuid-1.0.13 shtab-1.7.2 sqltrie-0.11.2 tomlkit-0.13.2 vine-5.1.0 voluptuous-0.15.2 zc.lockfile-3.0.post1

# %%
# !git clone https://github.com/aksel2904/en2ru.git
# Out:
# Cloning into 'en2ru'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 148 (delta 55), reused 120 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (148/148), 55.69 KiB | 5.06 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# %cd en2ru
# Out:
# /content/en2ru

# %%
# !pip install -r requirements.txt
# Out:
# Collecting pytorch-lightning (from -r requirements.txt (line 1))
#   Downloading pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.3.0)
# Collecting clearml (from -r requirements.txt (line 4))
#   Downloading clearml-1.18.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting sacrebleu (from -r requirements.txt (line 5))
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 1)) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (2025.3.2)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->-r requirements.txt (line 1))
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 1)) (4.13.1)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->-r requirements.txt (line 1))
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core->-r requirements.txt (line 2)) (4.9.3)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (25.3.0)
# Collecting furl>=2.0.0 (from clearml->-r requirements.txt (line 4))
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (4.23.0)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (2.0.2)
# Collecting pathlib2>=2.3.0 (from clearml->-r requirements.txt (line 4))
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: Pillow>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (5.9.5)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (2.3.0)
# Collecting pyjwt<2.10.0,>=2.4.0 (from clearml->-r requirements.txt (line 4))
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.11/dist-packages (from clearml->-r requirements.txt (line 4)) (0.36.2)
# Collecting portalocker (from sacrebleu->-r requirements.txt (line 5))
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu->-r requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu->-r requirements.txt (line 5)) (5.3.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (3.11.15)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml->-r requirements.txt (line 4))
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->clearml->-r requirements.txt (line 4)) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->clearml->-r requirements.txt (line 4)) (0.24.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml->-r requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->clearml->-r requirements.txt (line 4)) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 1)) (1.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1.0->pytorch-lightning->-r requirements.txt (line 1)) (3.0.2)
# Downloading pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 34.2 MB/s eta 0:00:00
# Downloading clearml-1.18.0-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.9 MB/s eta 0:00:00
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 10.4 MB/s eta 0:00:00
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 52.0 MB/s eta 0:00:00
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pyjwt, portalocker, pathlib2, orderedmultidict, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, sacrebleu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, furl, nvidia-cusolver-cu12, clearml, torchmetrics, pytorch-lightning
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.10.1
#     Uninstalling PyJWT-2.10.1:
#       Successfully uninstalled PyJWT-2.10.1
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed clearml-1.18.0 furl-2.1.4 lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 orderedmultidict-1.0.1 pathlib2-2.3.7.post1 portalocker-3.1.1 pyjwt-2.9.0 pytorch-lightning-2.5.1 sacrebleu-2.5.1 torchmetrics-1.7.1

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/en2ru
#   Preparing metadata (setup.py) ... done
# Installing collected packages: en2ru
#   Running setup.py develop for en2ru
# Successfully installed en2ru-0.1

# %%
'''!dvc config core.remote myremote
# !dvc remote add -d myremote gdrive://1tfX5r39iOMCZs7DbkB7s0Lwj-Fu1aWCm
# !dvc remote modify myremote gdrive_use_service_account true
# !dvc remote modify myremote gdrive_service_account_json_file_path dvc-sa.json'''
# Out:
# '!dvc config core.remote myremote\n!dvc remote add -d myremote gdrive://1tfX5r39iOMCZs7DbkB7s0Lwj-Fu1aWCm\n!dvc remote modify myremote gdrive_use_service_account true\n!dvc remote modify myremote gdrive_service_account_json_file_path dvc-sa.json'

# %%
# dvc-sa.json - загрузить перед этим в корень en2ru
# !dvc pull
# Out:
# Collecting          |21.0 [00:05, 3.51entry/s]
# Fetching
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Querying remote cache:   0% 0/3 [00:00<?, ?files/s]
# Querying remote cache:   0% 0/3 [00:00<?, ?files/s{'info': ''}]
# Querying remote cache:  33% 1/3 [00:00<00:01,  1.96files/s{'info': ''}]
#
# Fetching from gdrive:   0% 0/21 [00:00<?, ?file/s]
# Fetching from gdrive:   0% 0/21 [00:00<?, ?file/s{'info': ''}]
# Fetching from gdrive:   0% 0/6 [00:00<?, ?file/s{'info': ''}]
#
#   0% 0.00/20.3M [00:00<?, ?B/s]
#
#   0% 0.00/20.3M [00:00<?, ?B/s{'info': ''}]
#
# 100% 20.3M/20.3M [00:02<00:00, 9.88MB/s{'info': ''}]
#
#
# Fetching from gdrive:  17% 1/6 [00:03<00:14,  2.97s/file{'info': ''}]
#
#   0% 0.00/54.0M [00:00<?, ?B/s]
#
#   0% 0.00/54.0M [00:00<?, ?B/s{'info': ''}]
#
#
#   0% 0.00/204M [00:00<?, ?B/s]
#
#
#   0% 0.00/204M [00:00<?, ?B/s{'info': ''}]
#
#
#
#   0% 0.00/102M [00:00<?, ?B/s]
#
#
#
#   0% 0.00/102M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#   0% 0.00/108M [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/108M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#   0% 0.00/10.8M [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/10.8M [00:00<?, ?B/s{'info': ''}]
#
#
#
#  98% 100M/102M [00:01<00:00, 57.6MB/s{'info': ''}]
#
#
#
#
#  93% 100M/108M [00:01<00:00, 56.1MB/s{'info': ''}]
#
#
#  49% 100M/204M [00:01<00:01, 54.5MB/s{'info': ''}]
#
#
#
# 100% 102M/102M [00:02<00:00, 43.2MB/s{'info': ''}]
#
#
#
#
# Fetching from gdrive:  33% 2/6 [00:07<00:12,  3.23s/file{'info': ''}]
#
#
#
#
# 100% 108M/108M [00:02<00:00, 44.3MB/s{'info': ''}]
#
#
#
#
#
# Fetching from gdrive:  50% 3/6 [00:07<00:05,  1.81s/file{'info': ''}]
#
#
#  98% 200M/204M [00:03<00:00, 61.7MB/s{'info': ''}]
#
# 100% 54.0M/54.0M [00:04<00:00, 14.0MB/s{'info': ''}]
#
#
# Fetching from gdrive:  67% 4/6 [00:08<00:03,  1.68s/file{'info': ''}]
#
#
# 100% 204M/204M [00:03<00:00, 50.8MB/s{'info': ''}]
#
#
#
#
#
#
#
#
# 100% 10.8M/10.8M [00:10<00:00, 1.05MB/s{'info': ''}]
#
#
#
#
#
#
# Fetching from gdrive: 100% 6/6 [00:15<00:00,  2.60s/file{'info': ''}]
#
#   0% 0.00/452 [00:00<?, ?B/s]
#
#   0% 0.00/452 [00:00<?, ?B/s{'info': ''}]
#
# 100% 452/452 [00:00<00:00, 493B/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive              7/? [00:18<00:00,  2.56s/file]
#
#   0% 0.00/13.9M [00:00<?, ?B/s]
#
#   0% 0.00/13.9M [00:00<?, ?B/s{'info': ''}]
#
# 100% 13.9M/13.9M [00:06<00:00, 2.40MB/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive              8/? [00:26<00:00,  4.06s/file]
#
#   0% 0.00/138M [00:00<?, ?B/s]
#
#   0% 0.00/138M [00:00<?, ?B/s{'info': ''}]
#
#
#   0% 0.00/270M [00:00<?, ?B/s]
#
#
#   0% 0.00/270M [00:00<?, ?B/s{'info': ''}]
#
#
#
#   0% 0.00/69.0M [00:00<?, ?B/s]
#
#
#
#   0% 0.00/69.0M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#   0% 0.00/27.1M [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/27.1M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#   0% 0.00/135M [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/135M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#  74% 100M/135M [00:01<00:00, 76.0MB/s{'info': ''}]
#
#
#  37% 100M/270M [00:01<00:03, 59.3MB/s{'info': ''}]
#
#  72% 100M/138M [00:01<00:00, 57.3MB/s{'info': ''}]
#
#
#
#
#
# 100% 135M/135M [00:02<00:00, 56.3MB/s{'info': ''}]
#
#
#
#
#
#
#   0%|          |Fetching from gdrive              9/? [00:29<00:00,  3.88s/file]
#
#
#
#
# 100% 27.1M/27.1M [00:02<00:00, 11.7MB/s{'info': ''}]
#
#
#
#
#
#
# 100% 138M/138M [00:02<00:00, 52.5MB/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive             11/? [00:29<00:00,  2.19s/file]
#
#
#  74% 200M/270M [00:03<00:01, 59.5MB/s{'info': ''}]
#
#
# 100% 270M/270M [00:04<00:00, 64.0MB/s{'info': ''}]
#
#
#
#   0%|          |Fetching from gdrive             12/? [00:31<00:00,  2.11s/file]
#
#
#
# 100% 69.0M/69.0M [00:06<00:00, 11.1MB/s{'info': ''}]
#
#
#
#
#   0%|          |Fetching from gdrive             13/? [00:33<00:00,  2.08s/file]
#
#   0% 0.00/452 [00:00<?, ?B/s]
#
#   0% 0.00/452 [00:00<?, ?B/s{'info': ''}]
#
# 100% 452/452 [00:01<00:00, 287B/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive             14/? [00:37<00:00,  2.47s/file]
#
#   0% 0.00/4.27M [00:00<?, ?B/s]
#
#   0% 0.00/4.27M [00:00<?, ?B/s{'info': ''}]
#
# 100% 4.27M/4.27M [00:02<00:00, 1.53MB/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive             15/? [00:41<00:00,  3.09s/file]
#
#   0% 0.00/21.3M [00:00<?, ?B/s]
#
#   0% 0.00/21.3M [00:00<?, ?B/s{'info': ''}]
#
#
#   0% 0.00/36.5M [00:00<?, ?B/s]
#
#
#   0% 0.00/36.5M [00:00<?, ?B/s{'info': ''}]
#
#
#
#   0% 0.00/73.0M [00:00<?, ?B/s]
#
#
#
#   0% 0.00/73.0M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#   0% 0.00/42.6M [00:00<?, ?B/s]
#
#
#
#
#   0% 0.00/42.6M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
#   0% 0.00/7.31M [00:00<?, ?B/s]
#
#
#
#
#
#   0% 0.00/7.31M [00:00<?, ?B/s{'info': ''}]
#
#
#
#
#
# 100% 7.31M/7.31M [00:01<00:00, 5.84MB/s{'info': ''}]
#
#
#
#
#
#
#   0%|          |Fetching from gdrive             16/? [00:44<00:00,  2.95s/file]
#
# 100% 21.3M/21.3M [00:02<00:00, 9.62MB/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive             17/? [00:45<00:00,  2.36s/file]
#
#
#
#
# 100% 42.6M/42.6M [00:03<00:00, 11.8MB/s{'info': ''}]
#
#
#
#
#
#   0%|          |Fetching from gdrive             18/? [00:46<00:00,  2.10s/file]
#
#
# 100% 36.5M/36.5M [00:03<00:00, 9.86MB/s{'info': ''}]
#
#
#
#
#
#
# 100% 73.0M/73.0M [00:04<00:00, 16.4MB/s{'info': ''}]
#
#
#
#
#   0%|          |Fetching from gdrive             20/? [00:47<00:00,  1.35s/file]
#
#   0% 0.00/452 [00:00<?, ?B/s]
#
#   0% 0.00/452 [00:00<?, ?B/s{'info': ''}]
#
# 100% 452/452 [00:00<00:00, 656B/s{'info': ''}]
#
#
#   0%|          |Fetching from gdrive             21/? [00:49<00:00,  1.42s/file]
# Fetching
# Building workspace index          |1.00 [00:00, 38.6entry/s]
# Comparing indexes          |23.0 [00:00,  567entry/s]
# Applying changes          |18.0 [00:09,  1.92file/s]
# A       data/data1/
# A       data/data2/
# A       data/data3/
# 3 files added and 21 files fetched

# %%
# !python scripts/preprocess.py
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/data1/split_small/train.en
#   input_format:
#   model_prefix: data/data1/split_small/bpe_en
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <bos>
#   user_defined_symbols: <eos>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 2
#   eos_id: 3
#   pad_id: 1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: data/data1/split_small/train.en
# trainer_interface.cc(409) LOG(INFO) Loaded all 85000 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <bos>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <eos>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=9672026
# trainer_interface.cc(560) LOG(INFO) Alphabet size=805
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 85000 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 85000
# trainer_interface.cc(609) LOG(INFO) Done! 146922
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=221722 min_freq=29
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61513 size=20 all=6309 active=2091 piece=es
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36585 size=40 all=7421 active=3203 piece=ro
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18483 size=60 all=8880 active=4662 piece=▁for
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14342 size=80 all=10399 active=6181 piece=ow
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10969 size=100 all=11895 active=7677 piece=▁com
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10967 min_freq=928
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8781 size=120 all=13161 active=2239 piece=us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7903 size=140 all=14841 active=3919 piece=▁or
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6966 size=160 all=16949 active=6027 piece=ial
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5367 size=180 all=18255 active=7333 piece=ations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4752 size=200 all=19686 active=8764 piece=ther
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4743 min_freq=819
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4295 size=220 all=21000 active=2285 piece=vel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3917 size=240 all=22085 active=3370 piece=ance
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3613 size=260 all=23027 active=4312 piece=ine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3228 size=280 all=24499 active=5784 piece=ign
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2961 size=300 all=25295 active=6580 piece=ress
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2944 min_freq=568
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2768 size=320 all=26107 active=2018 piece=▁there
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2600 size=340 all=26746 active=2657 piece=ven
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2417 size=360 all=27467 active=3378 piece=▁dec
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2285 size=380 all=28445 active=4356 piece=ass
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2166 size=400 all=29551 active=5462 piece=rit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2164 min_freq=455
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2051 size=420 all=30643 active=2507 piece=ram
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1945 size=440 all=31494 active=3358 piece=▁inv
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1877 size=460 all=32034 active=3898 piece=▁includ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1755 size=480 all=32839 active=4703 piece=▁two
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1662 size=500 all=33460 active=5324 piece=stem
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1660 min_freq=371
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1598 size=520 all=34051 active=2253 piece=▁these
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1512 size=540 all=34655 active=2857 piece=▁produ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1442 size=560 all=34958 active=3160 piece=ower
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1386 size=580 all=35556 active=3758 piece=▁4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1349 size=600 all=36064 active=4266 piece=iew
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1348 min_freq=318
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1298 size=620 all=36895 active=2619 piece=▁did
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1239 size=640 all=37364 active=3088 piece=ient
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1189 size=660 all=38002 active=3726 piece=▁nations
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1159 size=680 all=38669 active=4393 piece=▁incre
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1128 size=700 all=39089 active=4813 piece=led
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1127 min_freq=276
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1104 size=720 all=39555 active=2370 piece=ather
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=12700 all=193359 active=9852 piece=▁францию
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=33 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=12720 all=193367 active=9676 piece=▁примеров
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=12740 all=193360 active=9669 piece=▁китайский
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=12760 all=193361 active=9670 piece=▁смертности
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=12780 all=193369 active=9678 piece=▁большинством
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=12800 all=193410 active=9719 piece=go
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=32 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=12820 all=193682 active=9930 piece=тью
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=12840 all=193917 active=10165 piece=пети
# trainer_interface.cc(687) LOG(INFO) Saving model: data/data1/split_small/bpe_ru.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: data/data1/split_small/bpe_ru.vocab

# %%
# !python src/train.py
# Out:
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# 🚀 Запуск обучения с конфигом:
# data:
#   dataset1_small_en: data/data1/dataset1_small.en
#   dataset1_small_ru: data/data1/dataset1_small.ru
#   dataset1_medium_en: data/data1/dataset1_medium.en
#   dataset1_medium_ru: data/data1/dataset1_medium.ru
#   dataset1_en: data/data1/dataset1.en
#   dataset1_ru: data/data1/dataset1.ru
#   dataset2_small_en: data/data2/dataset2_small.en
#   dataset2_small_ru: data/data2/dataset2_small.ru
#   dataset2_medium_en: data/data2/dataset2_medium.en
#   dataset2_medium_ru: data/data2/dataset2_medium.ru
#   dataset2_en: data/data2/dataset2.en
#   dataset2_ru: data/data2/dataset2.ru
#   dataset3_small_en: data/data3/dataset3_small.en
#   dataset3_small_ru: data/data3/dataset3_small.ru
#   dataset3_medium_en: data/data3/dataset3_medium.en
#   dataset3_medium_ru: data/data3/dataset3_medium.ru
#   dataset3_en: data/data3/dataset3.en
#   dataset3_ru: data/data3/dataset3.ru
#   train_src: data/data1/split_small/train.en
#   train_tgt: data/data1/split_small/train.ru
#   val_src: data/data1/split_small/val.en
#   val_tgt: data/data1/split_small/val.ru
#   test_src: data/data1/split_small/test.en
#   test_tgt: data/data1/split_small/test.ru
#   sp_model_src: data/data1/split_small/bpe_en.model
#   sp_model_tgt: data/data1/split_small/bpe_ru.model
#   batch_size: 64
#   num_workers: 0
# model:
#   input_dim: ???
#   output_dim: ???
#   enc_emb_dim: 32
#   dec_emb_dim: 32
#   enc_hid_dim: 64
#   dec_hid_dim: 64
#   attn_dim: 8
#   learning_rate: 0.001
# epochs: 10
#
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-04-18 07:54:22.660519: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744962862.682051   13414 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744962862.688902   13414 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-18 07:54:22.711779: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /content/en2ru/weights exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params | Mode
# -------------------------------------------------------
# 0 | model     | Seq2Seq          | 3.9 M  | train
# 1 | criterion | CrossEntropyLoss | 0      | train
# -------------------------------------------------------
# 3.9 M     Trainable params
# 0         Non-trainable params
# 3.9 M     Total params
# 15.521    Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 59. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 71. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Epoch 0:   3% 40/1329 [00:29<15:55,  1.35it/s, v_num=3]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# Epoch 0:   3% 40/1329 [00:46<24:45,  1.15s/it, v_num=3]
# ^C

# %%
# !python src/inference.py

# %%
# !python scripts/save_metrics.py

# %%
# !dvc add weights/best.ckpt
# !dvc add outputs/predictions.txt
# !dvc add outputs/metrics.json

# %%
# !git config --global user.name "yourname"
# !git config --global user.email "you@email.com"

# !git add weights/*.dvc outputs/*.dvc .gitignore
# !git commit -m "exp: , BLEU="
# !dvc push
